# %% [markdown]
# <a href="https://colab.research.google.com/github/jessika2018/Market-Basket-Analysis/blob/main/gergedatabase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mlxtend --upgrade
# Out:
# Collecting mlxtend
#   Downloading https://files.pythonhosted.org/packages/86/30/781c0b962a70848db83339567ecab656638c62f05adb064cb33c0ae49244/mlxtend-0.18.0-py2.py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.4MB 8.5MB/s
# Requirement already satisfied, skipping upgrade: pandas>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.1.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.13.2 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.0.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.2 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.19.5)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from mlxtend) (57.0.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (3.2.2)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->mlxtend) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->mlxtend) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->mlxtend) (1.15.0)
# Installing collected packages: mlxtend
#   Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.18.0

# %%
import mlxtend
print(mlxtend.__version__)
# Out:
# 0.18.0

# %%
# pip install squarify

# %%
#Data manipulation libraries
import pandas as pd
import numpy as np
#for market basket analysis (using apriori)
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth

#for preprocessing
from mlxtend.preprocessing import TransactionEncoder


#to print all the interactive output without resorting to print, not only the last result.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_excel("/content/Jessica.xlsx")
# df

# %%
test_df=pd.DataFrame(data=df, columns=['Product_Description'])

# %%
# intermediate_df = df['Product_Description'].str.split(';', expand=True).stack().str.strip().reset_index(level=1,drop=True)

# %%
# intermediate_df

# %%
# df
subset_df = df.sample(frac=.5)

# %%
# subset_df

# %%
# df2 = subset_df.groupby(by=['Group','Receipt_Number']).agg(text=("Item_Description", lambda x: ";".join(set(x))))
# df2
df2 = subset_df.groupby(by=['Invoice_id']).agg(text=("ProductDescription", lambda x: ";".join(set(x))))
# df2
# df2=subset_df.groupby("Group").agg({"Item_Description": np.sum, "Receipt_Number": lambda x: x.nunique()})
df2
# Out:
#                                                          text
# Invoice_id
# 1           Patch panel;K5e Cable Box 305m;Legrand cash ca...
# 2           Switching power supply;Standard Sony CCD 1/3" ...
# 3           Cabling, RG6, DC & flexible tubes;RG6 cable pe...
# 4           Standard Sony CCD 1/3" 420TVL with 6--16>mm va...
# 5           Mini bracket for camera;Cabling, RG6, DC & fle...
# ...                                                       ...
# 1703                                  Cable/meter;Accessories
# 1704        1-ch converter passive video balun;Hard disk 2...
# 1705               Coaxial, power, PVC tube with acc. + Labor
# 1709                       Software Version 2;Finger Print F7
# 1710                             Seal lead acid battery 150A
#
# [1395 rows x 1 columns]

# %%
# new_df = df2.iloc[:,0]

# %%
# new_df

# %%
# df2.Item_Description.nunique()

# %%
# df2.text.nunique()

# %%
# df["Group"] = df["Group"].str.lower()

# %%
df2["text"] = df2["text"].str.lower()

# %%
# df2["text"]

# %%
data = list(df2["text"].apply(lambda x:x.split(';')))
# data

# %%
te = TransactionEncoder()
te_data = te.fit(data).transform(data)
df = pd.DataFrame(te_data,columns=te.columns_)
df
# Out:
#       1 pair photo cell  ...  wise machine
# 0                 False  ...         False
# 1                 False  ...         False
# 2                 False  ...         False
# 3                 False  ...         False
# 4                 False  ...         False
# ...                 ...  ...           ...
# 1390              False  ...         False
# 1391              False  ...         False
# 1392              False  ...         False
# 1393              False  ...         False
# 1394              False  ...         False
#
# [1395 rows x 408 columns]

# %%
# # #Visualizations
# %matplotlib inline
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_style("dark")
# import squarify
# import matplotlib

# %%
# ##Lets consider the top 20 items purchased freequently
# r=df.sum(axis=0).sort_values(ascending=False)[:20]
# #altering the figsize
# plt.figure(figsize=(20,10))
# s=sns.barplot(x=r.index,y=r.values)
# s.set_xticklabels(s.get_xticklabels(), rotation=90)

# %%
# # create a color palette, mapped to these values
# my_values=r.values
# cmap = matplotlib.cm.Blues
# mini=min(my_values)
# maxi=max(my_values)
# norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
# colors = [cmap(norm(value)) for value in my_values]


# #treemap of top 20 frequent items
# plt.figure(figsize=(10,10))
# squarify.plot(sizes=r.values, label=r.index, alpha=.7,color=colors)
# plt.title("Tree map of top 20 items")
# plt.axis('off')

# %%
frequent_itemsets = apriori(df,min_support=0.04,use_colnames=True)
frequent_itemsets
# Out:
#      support                                          itemsets
# 0   0.040860                           (3m cat6 cable / meter)
# 1   0.043728              (3m/legrand rj 45 converter 22.5x45)
# 2   0.129749                                     (accessories)
# 3   0.041577                                     (blank cover)
# 4   0.083154                                  (bnc & dc plugs)
# 5   0.050896                                (cctv accessories)
# 6   0.049462                                   (cctv camera\n)
# 7   0.076703      (coaxial, power, pvc tube with acc. + labor)
# 8   0.043728                                 (complete outlet)
# 9   0.362007               (connection, testing, termination )
# 10  0.083871                         (data outlet utp cat6 3m)
# 11  0.047312                   (legrand box + chassis + cover)
# 12  0.068100              (maintenance agreement for 1 year\n)
# 13  0.054480            (switching power supply metal case 1a)
# 14  0.040143                                           (tubes)
# 15  0.052330  (connection, testing, termination , accessories)

# %%
res=association_rules(frequent_itemsets,metric="lift",min_threshold=1)
res
# Out:
#                            antecedents  ... conviction
# 0  (connection, testing, termination )  ...   1.017307
# 1                        (accessories)  ...   1.069229
#
# [2 rows x 9 columns]

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x:len(x))
frequent_itemsets
# Out:
#      support                                          itemsets  length
# 0   0.040860                           (3m cat6 cable / meter)       1
# 1   0.043728              (3m/legrand rj 45 converter 22.5x45)       1
# 2   0.129749                                     (accessories)       1
# 3   0.041577                                     (blank cover)       1
# 4   0.083154                                  (bnc & dc plugs)       1
# 5   0.050896                                (cctv accessories)       1
# 6   0.049462                                   (cctv camera\n)       1
# 7   0.076703      (coaxial, power, pvc tube with acc. + labor)       1
# 8   0.043728                                 (complete outlet)       1
# 9   0.362007               (connection, testing, termination )       1
# 10  0.083871                         (data outlet utp cat6 3m)       1
# 11  0.047312                   (legrand box + chassis + cover)       1
# 12  0.068100              (maintenance agreement for 1 year\n)       1
# 13  0.054480            (switching power supply metal case 1a)       1
# 14  0.040143                                           (tubes)       1
# 15  0.052330  (connection, testing, termination , accessories)       2

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.02) ]
# Out:
#     support                                          itemsets  length
# 15  0.05233  (connection, testing, termination , accessories)       2

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 1) &
                   (frequent_itemsets['support'] >= 0.01) ]
# Out:
#      support                                      itemsets  length
# 0   0.040860                       (3m cat6 cable / meter)       1
# 1   0.043728          (3m/legrand rj 45 converter 22.5x45)       1
# 2   0.129749                                 (accessories)       1
# 3   0.041577                                 (blank cover)       1
# 4   0.083154                              (bnc & dc plugs)       1
# 5   0.050896                            (cctv accessories)       1
# 6   0.049462                               (cctv camera\n)       1
# 7   0.076703  (coaxial, power, pvc tube with acc. + labor)       1
# 8   0.043728                             (complete outlet)       1
# 9   0.362007           (connection, testing, termination )       1
# 10  0.083871                     (data outlet utp cat6 3m)       1
# 11  0.047312               (legrand box + chassis + cover)       1
# 12  0.068100          (maintenance agreement for 1 year\n)       1
# 13  0.054480        (switching power supply metal case 1a)       1
# 14  0.040143                                       (tubes)       1

# %%
# rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=1)
# rules

# %%
frequent_itemset_fp_growth=fpgrowth(df,min_support=0.04,use_colnames=True)
frequent_itemset_fp_growth = frequent_itemset_fp_growth.sort_values(by="support",ascending=False)
frequent_itemset_fp_growth
# Out:
#      support                                          itemsets
# 1   0.362007               (connection, testing, termination )
# 9   0.129749                                     (accessories)
# 6   0.083871                         (data outlet utp cat6 3m)
# 0   0.083154                                  (bnc & dc plugs)
# 2   0.076703      (coaxial, power, pvc tube with acc. + labor)
# 7   0.068100              (maintenance agreement for 1 year\n)
# 5   0.054480            (switching power supply metal case 1a)
# 15  0.052330  (connection, testing, termination , accessories)
# 13  0.050896                                (cctv accessories)
# 14  0.049462                                   (cctv camera\n)
# 3   0.047312                   (legrand box + chassis + cover)
# 4   0.043728              (3m/legrand rj 45 converter 22.5x45)
# 10  0.043728                                 (complete outlet)
# 11  0.041577                                     (blank cover)
# 12  0.040860                           (3m cat6 cable / meter)
# 8   0.040143                                           (tubes)

# %%
res=association_rules(frequent_itemset_fp_growth,metric="lift",min_threshold=1)
res = res.sort_values(by="lift",ascending=False)
res
# Out:
#                            antecedents  ... conviction
# 0  (connection, testing, termination )  ...   1.017307
# 1                        (accessories)  ...   1.069229
#
# [2 rows x 9 columns]

# %%
frequent_itemsets.sort_values(by="support",ascending=False)
# Out:
#      support                                          itemsets  length
# 9   0.362007               (connection, testing, termination )       1
# 2   0.129749                                     (accessories)       1
# 10  0.083871                         (data outlet utp cat6 3m)       1
# 4   0.083154                                  (bnc & dc plugs)       1
# 7   0.076703      (coaxial, power, pvc tube with acc. + labor)       1
# 12  0.068100              (maintenance agreement for 1 year\n)       1
# 13  0.054480            (switching power supply metal case 1a)       1
# 15  0.052330  (connection, testing, termination , accessories)       2
# 5   0.050896                                (cctv accessories)       1
# 6   0.049462                                   (cctv camera\n)       1
# 11  0.047312                   (legrand box + chassis + cover)       1
# 1   0.043728              (3m/legrand rj 45 converter 22.5x45)       1
# 8   0.043728                                 (complete outlet)       1
# 3   0.041577                                     (blank cover)       1
# 0   0.040860                           (3m cat6 cable / meter)       1
# 14  0.040143                                           (tubes)       1
