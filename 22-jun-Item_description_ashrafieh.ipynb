# %% [markdown]
# <a href="https://colab.research.google.com/github/jessika2018/Market-Basket-Analysis/blob/main/22-jun-Item_description_ashrafieh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mlxtend --upgrade
# Out:
# Requirement already up-to-date: mlxtend in /usr/local/lib/python3.7/dist-packages (0.18.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.2 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.19.5)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from mlxtend) (57.0.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.1.5)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (3.2.2)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: scipy>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.13.2 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.0.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->mlxtend) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->mlxtend) (2018.9)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.4.7)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->mlxtend) (1.15.0)

# %%
import mlxtend
print(mlxtend.__version__)
# Out:
# 0.18.0

# %%
# pip install squarify

# %%
#Data manipulation libraries
import pandas as pd
import numpy as np
#for market basket analysis (using apriori)
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth

#for preprocessing
from mlxtend.preprocessing import TransactionEncoder


#to print all the interactive output without resorting to print, not only the last result.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_excel("/content/Ashrafieh Sales.xlsx")
# df

# %%
# test_df=pd.DataFrame(data=df, columns=['Item_Description'])

# %%
# intermediate_df = df['Item_Description'].str.split(';', expand=True).stack().str.strip().reset_index(level=1,drop=True)

# %%
# intermediate_df

# %%
# df
subset_df = df.sample(frac=.5)

# %%
# subset_df

# %%
# df2 = subset_df.groupby(by=['Group','Receipt_Number']).agg(text=("Item_Description", lambda x: ";".join(set(x))))
# df2
df2 = subset_df.groupby(by=['Group']).agg(text=("Item_Description", lambda x: ";".join(set(x))))
# df2
# df2=subset_df.groupby("Group").agg({"Item_Description": np.sum, "Receipt_Number": lambda x: x.nunique()})
# df2

# %%
# new_df = df2.iloc[:,0]

# %%
# new_df

# %%
# df2.Item_Description.nunique()

# %%
# df2.text.nunique()

# %%
# df["Group"] = df["Group"].str.lower()

# %%
df2["text"] = df2["text"].str.lower()

# %%
# df2["text"]
# Out:
# Group
# AIR FRESHNERS            hang it fresh cool;desodorisant fleur cerise;d...
# ALL PUPROSE              2 apc jasmine-30%;fresh lemon -20%;3en1 gel av...
# ALUMINUM FOIL & CLING    cling film 300 yards;snap&seal freezer bags;al...
# ANTISEPTICS              fruit & veg sanitizer;buys bts antiseptic 1+1;...
# BABY CARE                value large plus  - 3000 ll;baby powder;ab jum...
#                                                ...
# VEGAN                    tomato&basilic portions;mozzarella slices;orig...
# WATER                    eau minerale;min water prestige;orange mango;p...
# WHISKY                   black label 12y;single whisky 15 ans 40d;whisk...
# WINE                     prosecco extra dry;vin bordeaux;cellier d or v...
# YOGHURTS                 greek style yogurt blueberry;caramel desert;wi...
# Name: text, Length: 99, dtype: object

# %%
data = list(df2["text"].apply(lambda x:x.split(';')))
# data

# %%
te = TransactionEncoder()
te_data = te.fit(data).transform(data)
df = pd.DataFrame(te_data,columns=te.columns_)
df
# Out:
#     1% CHOCOLATE MILK RTD ASP  ...  ZWAN MORTADELLA OLIVE
# 0                       False  ...                  False
# 1                       False  ...                  False
# 2                       False  ...                  False
# 3                       False  ...                  False
# 4                       False  ...                  False
# ..                        ...  ...                    ...
# 93                      False  ...                  False
# 94                      False  ...                  False
# 95                      False  ...                  False
# 96                      False  ...                  False
# 97                      False  ...                  False
#
# [98 rows x 9696 columns]

# %%
# #Visualizations
# %matplotlib inline
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_style("dark")
# import squarify
# import matplotlib

# %%
# ##Lets consider the top 20 items purchased freequently
# r=df.sum(axis=0).sort_values(ascending=False)[:20]
# #altering the figsize
# plt.figure(figsize=(20,10))
# s=sns.barplot(x=r.index,y=r.values)
# s.set_xticklabels(s.get_xticklabels(), rotation=90)

# %%
# # create a color palette, mapped to these values
# my_values=r.values
# cmap = matplotlib.cm.Blues
# mini=min(my_values)
# maxi=max(my_values)
# norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
# colors = [cmap(norm(value)) for value in my_values]


# #treemap of top 20 frequent items
# plt.figure(figsize=(10,10))
# squarify.plot(sizes=r.values, label=r.index, alpha=.7,color=colors)
# plt.title("Tree map of top 20 items")
# plt.axis('off')

# %%
frequent_itemsets = apriori(df,min_support=0.02,use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.020408                                      (APPLE JUICE)
# 1   0.020408                                (ARTICHOKE BOTTOMS)
# 2   0.020408                                         (BROWNIES)
# 3   0.020408                                           (CASHEW)
# 4   0.020408                                       (CHICK PEAS)
# ..       ...                                                ...
# 72  0.020408  (GREEN ASPARAGUS, ARTICHOKE BOTTOMS, FINE GREE...
# 73  0.020408  (GOLDEN SWEET CORN, ARTICHOKE BOTTOMS, MIXED V...
# 74  0.020408  (STRAWBERRY CHEESE CAKE, FONDANT AU CHOCOLAT, ...
# 75  0.020408  (GREEN ASPARAGUS, FINE GREEN BEANS, MIXED VEGE...
# 76  0.020408  (GREEN ASPARAGUS, FINE GREEN BEANS, GOLDEN SWE...
#
# [77 rows x 2 columns]

# %%
res=association_rules(frequent_itemsets,metric="lift",min_threshold=1.3)
res
# Out:
#              antecedents  ... conviction
# 0          (APPLE JUICE)  ...        inf
# 1         (ORANGE JUICE)  ...        inf
# 2    (ARTICHOKE BOTTOMS)  ...        inf
# 3     (FINE GREEN BEANS)  ...        inf
# 4    (GOLDEN SWEET CORN)  ...        inf
# ..                   ...  ...        ...
# 235    (GREEN ASPARAGUS)  ...        inf
# 236   (FINE GREEN BEANS)  ...        inf
# 237  (GOLDEN SWEET CORN)  ...        inf
# 238  (ARTICHOKE BOTTOMS)  ...        inf
# 239   (MIXED VEGETABLES)  ...        inf
#
# [240 rows x 9 columns]

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x:len(x))
frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.020408                                      (APPLE JUICE)       1
# 1   0.020408                                (ARTICHOKE BOTTOMS)       1
# 2   0.020408                                         (BROWNIES)       1
# 3   0.020408                                           (CASHEW)       1
# 4   0.020408                                       (CHICK PEAS)       1
# ..       ...                                                ...     ...
# 72  0.020408  (GREEN ASPARAGUS, ARTICHOKE BOTTOMS, FINE GREE...       4
# 73  0.020408  (GOLDEN SWEET CORN, ARTICHOKE BOTTOMS, MIXED V...       4
# 74  0.020408  (STRAWBERRY CHEESE CAKE, FONDANT AU CHOCOLAT, ...       4
# 75  0.020408  (GREEN ASPARAGUS, FINE GREEN BEANS, MIXED VEGE...       4
# 76  0.020408  (GREEN ASPARAGUS, FINE GREEN BEANS, GOLDEN SWE...       5
#
# [77 rows x 3 columns]

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.01) ]
# Out:
#      support                                       itemsets  length
# 35  0.020408                    (APPLE JUICE, ORANGE JUICE)       2
# 36  0.020408          (ARTICHOKE BOTTOMS, FINE GREEN BEANS)       2
# 37  0.020408         (GOLDEN SWEET CORN, ARTICHOKE BOTTOMS)       2
# 38  0.020408           (GREEN ASPARAGUS, ARTICHOKE BOTTOMS)       2
# 39  0.020408          (ARTICHOKE BOTTOMS, MIXED VEGETABLES)       2
# 40  0.020408                            (CASHEW, PISTACHIO)       2
# 41  0.020408         (FONDANT AU CHOCOLAT, CHOCOLATE FUDGE)       2
# 42  0.020408                   (CHOCOLATE FUDGE, PISTACHIO)       2
# 43  0.020408      (STRAWBERRY CHEESE CAKE, CHOCOLATE FUDGE)       2
# 44  0.020408              (CRACKERS CHEESE, CRACKERS PIZZA)       2
# 45  0.020408          (GOLDEN SWEET CORN, FINE GREEN BEANS)       2
# 46  0.020408            (GREEN ASPARAGUS, FINE GREEN BEANS)       2
# 47  0.020408           (FINE GREEN BEANS, MIXED VEGETABLES)       2
# 48  0.020408               (FONDANT AU CHOCOLAT, PISTACHIO)       2
# 49  0.020408  (STRAWBERRY CHEESE CAKE, FONDANT AU CHOCOLAT)       2
# 50  0.020408                    (GOAT CHEESE, WHITE CHEESE)       2
# 51  0.020408           (GREEN ASPARAGUS, GOLDEN SWEET CORN)       2
# 52  0.020408          (GOLDEN SWEET CORN, MIXED VEGETABLES)       2
# 53  0.020408            (GREEN ASPARAGUS, MIXED VEGETABLES)       2
# 54  0.020408           (HOMMOS READY TO EAT, HOMMOS TAHINA)       2
# 55  0.020408            (STRAWBERRY CHEESE CAKE, PISTACHIO)       2

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 1) &
                   (frequent_itemsets['support'] >= 0.01) ]
# Out:
#      support                  itemsets  length
# 0   0.020408             (APPLE JUICE)       1
# 1   0.020408       (ARTICHOKE BOTTOMS)       1
# 2   0.020408                (BROWNIES)       1
# 3   0.020408                  (CASHEW)       1
# 4   0.020408              (CHICK PEAS)       1
# 5   0.020408         (CHOCOLATE FUDGE)       1
# 6   0.020408                 (COCONUT)       1
# 7   0.020408         (CRACKERS CHEESE)       1
# 8   0.020408          (CRACKERS PIZZA)       1
# 9   0.020408            (CREAM CHEESE)       1
# 10  0.020408                   (CREME)       1
# 11  0.020408   (CROISSANT AU CHOCOLAT)       1
# 12  0.020408        (FINE GREEN BEANS)       1
# 13  0.020408     (FONDANT AU CHOCOLAT)       1
# 14  0.020408          (FRUIT COCKTAIL)       1
# 15  0.020408           (GINGER POWDER)       1
# 16  0.020408             (GOAT CHEESE)       1
# 17  0.020408       (GOLDEN SWEET CORN)       1
# 18  0.020408         (GREEN ASPARAGUS)       1
# 19  0.020408     (HOMMOS READY TO EAT)       1
# 20  0.020408           (HOMMOS TAHINA)       1
# 21  0.020408                 (KETCHUP)       1
# 22  0.020408        (MIXED VEGETABLES)       1
# 23  0.020408        (NON WOVEN STRIPS)       1
# 24  0.020408            (ORANGE JUICE)       1
# 25  0.020408   (ORGANIC SMOKED SALMON)       1
# 26  0.020408          (PAPIER CUISSON)       1
# 27  0.020408                 (PAPRIKA)       1
# 28  0.020408              (PEPPERMINT)       1
# 29  0.030612               (PISTACHIO)       1
# 30  0.020408                   (PLUMS)       1
# 31  0.020408               (SPAGHETTI)       1
# 32  0.020408  (STRAWBERRY CHEESE CAKE)       1
# 33  0.020408                 (WALNUTS)       1
# 34  0.020408            (WHITE CHEESE)       1

# %%
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.5)

# %%
frequent_itemset_fp_growth=fpgrowth(df,min_support=0.22,use_colnames=True)
frequent_itemset_fp_growth = frequent_itemset_fp_growth.sort_values(by="support",ascending=False)
frequent_itemset_fp_growth
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
res=association_rules(frequent_itemset_fp_growth,metric="lift",min_threshold=1)
res = res.sort_values(by="lift",ascending=False)
res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-3796780a5f60> in <module>()
# ----> 1 res=association_rules(frequent_itemset_fp_growth,metric="lift",min_threshold=1)
#       2 res = res.sort_values(by="lift",ascending=False)
#       3 res
#
# /usr/local/lib/python3.7/dist-packages/mlxtend/frequent_patterns/association_rules.py in association_rules(df, metric, min_threshold, support_only)
#     127     values = df['support'].values
#     128     frozenset_vect = np.vectorize(lambda x: frozenset(x))
# --> 129     frequent_items_dict = dict(zip(frozenset_vect(keys), values))
#     130
#     131     # prepare buckets to collect frequent rules
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2106             vargs.extend([kwargs[_n] for _n in names])
#    2107
# -> 2108         return self._vectorize_call(func=func, args=vargs)
#    2109
#    2110     def _get_ufunc_and_otypes(self, func, args):
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2184             res = func()
#    2185         else:
# -> 2186             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2187
#    2188             # Convert args to object arrays first
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2140             args = [asarray(arg) for arg in args]
#    2141             if builtins.any(arg.size == 0 for arg in args):
# -> 2142                 raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2143                                  'unless `otypes` is set')
#    2144
#
# ValueError: cannot call `vectorize` on size 0 inputs unless `otypes` is set

# %%
frequent_itemsets.sort_values(by="support",ascending=False)
